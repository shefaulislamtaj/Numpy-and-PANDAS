# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
categories = np.array(['Grains','Fruit','Vegetables','Protein','Dairy','Sweets'])
Values = np.array([4,3,2,5,3,1])

# %%
#plt.plot(categories,Values) 
#plt.barh(categories,Values, color = '#43f577')
plt.bar(categories,Values, color = '#43f577') 
plt.title('Dayily Consumption')
plt.xlabel('Food',
          color = 'red')#42f557
plt.ylabel('Quantity', color = '#42f557')
#plt.grid(axis = 'y',
         #linewidth = '1',
    #color = '#f803fc',
    #linestyle = 'dotted',   
#)
# Out:
# Text(0, 0.5, 'Quantity')
