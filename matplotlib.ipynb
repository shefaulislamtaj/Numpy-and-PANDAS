# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = [1,2,3,4,5]
y = [5,10,15,20,25]

# %%
plt.plot(x,y) 
plt.grid(axis = 'y',
         linewidth = '1',
    color = 'blue',
    linestyle = 'dotted',   
)
